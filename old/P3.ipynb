# %%
# !python -V
# !pip install turicreate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 19.1 MB/s eta 0:00:0000:0100:01
# Collecting resampy==0.2.1
#   Downloading resampy-0.2.1.tar.gz (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 KB 15.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting coremltools==3.3
#   Downloading coremltools-3.3-cp37-none-manylinux1_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 18.9 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow<2.1.0,>=2.0.0
#   Downloading tensorflow-2.0.4-cp37-cp37m-manylinux2010_x86_64.whl (86.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.4/86.4 MB 11.6 MB/s eta 0:00:0000:0100:01
# Collecting numpy
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 16.8 MB/s eta 0:00:0000:0100:01
# Collecting pandas>=0.23.2
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 19.6 MB/s eta 0:00:0000:0100:01
# Collecting requests>=2.9.1
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Requirement already satisfied: six>=1.10.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (1.16.0)
# Collecting prettytable==0.7.2
#   Downloading prettytable-0.7.2.zip (28 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pillow>=5.2.0
#   Downloading Pillow-9.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 21.3 MB/s eta 0:00:0000:0100:01
# Collecting numba<0.51.0
#   Downloading numba-0.50.1-cp37-cp37m-manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 21.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: decorator>=4.0.9 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (5.1.1)
# Collecting protobuf>=3.1.0
#   Downloading protobuf-3.20.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from numba<0.51.0->turicreate) (62.1.0)
# Collecting llvmlite<0.34,>=0.33.0.dev0
#   Downloading llvmlite-0.33.0-cp37-cp37m-manylinux1_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 21.3 MB/s eta 0:00:0000:0100:01
# Collecting pytz>=2017.3
#   Using cached pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from pandas>=0.23.2->turicreate) (2.8.2)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0
#   Using cached charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Collecting h5py<=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 26.1 MB/s eta 0:00:0000:0100:01
# Collecting absl-py>=0.7.0
#   Using cached absl_py-1.0.0-py3-none-any.whl (126 kB)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading tensorboard-2.0.2-py3-none-any.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 25.8 MB/s eta 0:00:0000:0100:01
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 KB 7.8 MB/s eta 0:00:00
# Collecting google-pasta>=0.1.6
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: wheel>=0.26 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.37.1)
# Collecting numpy
#   Downloading numpy-1.18.5-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 22.7 MB/s eta 0:00:0000:0100:01
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting astor>=0.6.0
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting wrapt>=1.11.1
#   Downloading wrapt-1.14.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.2/75.2 KB 5.8 MB/s eta 0:00:00
# Collecting grpcio>=1.8.6
#   Downloading grpcio-1.44.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 22.8 MB/s eta 0:00:0000:0100:01
# Collecting keras-preprocessing>=1.0.5
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.9/449.9 KB 20.5 MB/s eta 0:00:00
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.1.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.7/224.7 KB 14.5 MB/s eta 0:00:00
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 KB 13.6 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.6-py3-none-any.whl (97 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.8-py3-none-any.whl (39 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (3.8.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Building wheels for collected packages: prettytable, resampy, gast, termcolor
#   Building wheel for prettytable (setup.py) ... done
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13714 sha256=2cc0341786c7141a279426e061d9877c3f6095f44bbe2438b9a784bd4deee5c2
#   Stored in directory: /home/azalea/.cache/pip/wheels/b2/7f/f6/f180315b584f00445045ff1699b550fa895d09471337ce21c6
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.1-py3-none-any.whl size=320860 sha256=0e66f2a52816a279650d9fd3d7903fea941d9948fee3f9ea095e3466bc0f9d7f
#   Stored in directory: /home/azalea/.cache/pip/wheels/71/74/53/d5ceb7c5ee7a168c7d106041863e71ac3273f4a4677743a284
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=d4fe4f17f00e4ab6c7477385868bbd86182300a0a7943c31d96d0a7114897b61
#   Stored in directory: /home/azalea/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=f80187ab64bc01b8bf42617dba5e36e19c3c66919180e49efdb52084ee946f75
#   Stored in directory: /home/azalea/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# Successfully built prettytable resampy gast termcolor
# Installing collected packages: termcolor, tensorflow-estimator, pytz, pyasn1, prettytable, certifi, wrapt, werkzeug, urllib3, rsa, pyasn1-modules, protobuf, pillow, oauthlib, numpy, llvmlite, idna, grpcio, google-pasta, gast, charset-normalizer, cachetools, astor, absl-py, scipy, requests, pandas, opt-einsum, numba, markdown, keras-preprocessing, h5py, google-auth, coremltools, resampy, requests-oauthlib, keras-applications, google-auth-oauthlib, tensorboard, tensorflow, turicreate
# Successfully installed absl-py-1.0.0 astor-0.8.1 cachetools-4.2.4 certifi-2021.10.8 charset-normalizer-2.0.12 coremltools-3.3 gast-0.2.2 google-auth-1.35.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.44.0 h5py-2.10.0 idna-3.3 keras-applications-1.0.8 keras-preprocessing-1.1.2 llvmlite-0.33.0 markdown-3.3.6 numba-0.50.1 numpy-1.18.5 oauthlib-3.2.0 opt-einsum-3.3.0 pandas-1.3.5 pillow-9.1.0 prettytable-0.7.2 protobuf-3.20.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 pytz-2022.1 requests-2.27.1 requests-oauthlib-1.3.1 resampy-0.2.1 rsa-4.8 scipy-1.7.3 tensorboard-2.0.2 tensorflow-2.0.4 tensorflow-estimator-2.0.1 termcolor-1.1.0 turicreate-6.4.1 urllib3-1.26.9 werkzeug-2.1.1 wrapt-1.14.0
# Python 3.7.13
# Requirement already satisfied: turicreate in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (6.4.1)
# Requirement already satisfied: pillow>=5.2.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (9.1.0)
# Requirement already satisfied: tensorflow<2.1.0,>=2.0.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (2.0.4)
# Requirement already satisfied: pandas>=0.23.2 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (1.3.5)
# Requirement already satisfied: six>=1.10.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (1.16.0)
# Requirement already satisfied: prettytable==0.7.2 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (0.7.2)
# Requirement already satisfied: requests>=2.9.1 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (2.27.1)
# Requirement already satisfied: numpy in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (1.18.5)
# Requirement already satisfied: coremltools==3.3 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (3.3)
# Requirement already satisfied: resampy==0.2.1 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (0.2.1)
# Requirement already satisfied: decorator>=4.0.9 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (5.1.1)
# Requirement already satisfied: numba<0.51.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (0.50.1)
# Requirement already satisfied: scipy>=1.1.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from turicreate) (1.7.3)
# Requirement already satisfied: protobuf>=3.1.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from coremltools==3.3->turicreate) (3.20.1)
# Requirement already satisfied: setuptools in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from numba<0.51.0->turicreate) (62.1.0)
# Requirement already satisfied: llvmlite<0.34,>=0.33.0.dev0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from numba<0.51.0->turicreate) (0.33.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from pandas>=0.23.2->turicreate) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from pandas>=0.23.2->turicreate) (2022.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from requests>=2.9.1->turicreate) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from requests>=2.9.1->turicreate) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from requests>=2.9.1->turicreate) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from requests>=2.9.1->turicreate) (2.0.12)
# Requirement already satisfied: astor>=0.6.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.8.1)
# Requirement already satisfied: gast==0.2.2 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.2.2)
# Requirement already satisfied: wrapt>=1.11.1 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.14.0)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (2.0.2)
# Requirement already satisfied: absl-py>=0.7.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.0.0)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (2.0.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.2.0)
# Requirement already satisfied: grpcio>=1.8.6 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.44.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (1.1.2)
# Requirement already satisfied: wheel>=0.26 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (0.37.1)
# Requirement already satisfied: h5py<=2.10.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorflow<2.1.0,>=2.0.0->turicreate) (2.10.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (2.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/azalea/.conda/envs/p3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow<2.1.0,>=2.0.0->turicreate) (3.2.0)

# %%
# !pip install gensim
# !pip install --upgrade numpy
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.18.5)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.18.5)
# Collecting numpy
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 5.4 MB/s
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.0.4 requires numpy<1.19.0,>=1.16.0, but you have numpy 1.21.6 which is incompatible.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# librosa 0.8.1 requires resampy>=0.2.2, but you have resampy 0.2.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.21.6

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Data Preprocessing & NLP
import nltk
import re
import string
import gensim
from textblob import Word
from ast import literal_eval
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem import PorterStemmer
from nltk.stem.porter import *
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Data Cleaning
whitelist = set('abcdefghijklmnopqrstuvwxyz ABCDEFGHIJKLMNOPQRSTUVWXYZ')
def clean_text(text):
  text = ''.join(filter(whitelist.__contains__, text))
  text = text.lower()
  return text

# %%
from itertools import count
# Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

def random_color_func(word=None, font_size=None, position=None,
                      orientation=None, font_path=None, random_state=None):
    h = int(360.0 * 55.0 / 255.0)
    s = int(100.0 * 255.0 / 255.0)
    l = int(100.0 * float(random_state.randint(70, 120)) / 255.0)
    return "hsl({}, {}%, {}%)".format(h, s, l)

def freq_words(x, terms = 40):
    all_words = ' '.join([text for text in x])
    all_words = all_words.split()
    
    freq_dist = nltk.FreqDist(all_words)
    words_df = pd.DataFrame({'word':list(freq_dist.keys()), 'count':list(freq_dist.values())})
    
    fig = plt.figure(figsize=(21,16))
    ax1 = fig.add_subplot(2,1,1)
    wordcloud = WordCloud(width=1000, height=300, background_color='black', 
                          max_words=1628, relative_scaling=1,
                          color_func = random_color_func,
                          normalize_plurals=False).generate_from_frequencies(freq_dist)
    
    ax1.imshow(wordcloud, interpolation="bilinear")
    ax1.axis('off')
    
    # select top 40 most frequent word
    ax2 = fig.add_subplot(2,1,2)
    d = words_df.nlargest(columns="count", n = terms) 
    ax2 = sns.barplot(data=d, palette = sns.color_palette('BuGn_r'), x= "count", y = "word")
    ax2.set(ylabel= 'Word')
    plt.show()

# %%
# stopwords-to compare text data with and without stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# function to remove stopwords
def remove_stopwords(text):
    no_stopword_text = [w for w in text.split() if not w in stop_words]
    return ' '.join(no_stopword_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# stemming process
'''
Words in the third person are changed to first person and verbs in past and future tenses are changed into the present by the 
stemming process. 
'''
stem_process = PorterStemmer()

def tokenize_and_stem(text):
    # tokenization to ensure that punctuation is caught as its own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    lem = [stem_process.stem(t) for t in filtered_tokens]
    return lem

# %%
dataset = pd.read_csv('reviews.csv', encoding='ISO-8859-1')

# change name of columns (remove 'IS_')
for col in dataset.columns[15:]:
    dataset = dataset.rename(columns = {col:col[3:]})

# Data Cleaning
dataset['clean_reviewText'] = dataset['reviewText'].apply(clean_text)
dataset['soup'] = dataset['clean_reviewText']

# %%
sns.set()
# %matplotlib inline
word = freq_words(dataset['soup'])

# %%
dataset['soup'] = dataset['soup'].apply(lambda x: remove_stopwords(x))

# %%
# # plot 50 most frequent words without stopwords
freq_words(dataset['soup'], 50)


# total words count of user reviews
wordcounts = []
sentences = dataset['soup']
for sentence in sentences:
  words = sentence.split(' ')
  wordcounts.append(len(words))
print(sum(wordcounts))
# Out:
# 94007

# %%
text = " ".join(review for review in dataset.clean_reviewText)
wordcloud = WordCloud(width=1600, height=800,max_font_size=200, colormap='magma').generate(text)

plt.figure(figsize = (12, 10))
plt.imshow(wordcloud, interpolation='spline36')
plt.axis("off")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.multiclass import OneVsRestClassifier
import collections
from sklearn.ensemble import GradientBoostingRegressor
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support as score

def get_performance(y_true, y_pred):
  # classification_result = classification_report(y_true, y_pred, target_names=['0','1'])
  # print(classification_result)
  # Evaluate Performance
  accuracy = round(accuracy_score(y_true, y_pred) * 100, 2)
  # Get precision, recall, f1 scores
  precision, recall, f1score, support = score(y_true, y_pred, pos_label=1, average='binary')
  return accuracy, precision, recall, f1score

# %%
all_categories = ['APP USABILITY', 'UI', 'DEVICE', 'ANDROID VERSION', 'HARDWARE', 'PERFORMANCE', 'BATTERY', 'MEMORY', 'LICENSING', 'PRICE', 'PRIVACY', 'SECURITY', 'USAGE', 'COMPATIBILITY', 'RESSOURCES', 'PRICING', 'PROTECTION', 'ERROR']
# all_categories = ['APP USABILITY', 'UI', 'DEVICE', 'ANDROID VERSION', 'HARDWARE', 'PERFORMANCE', 'BATTERY', 'MEMORY', 'LICENSING', 'PRICE', 'PRIVACY', 'SECURITY']

# %%
# Defining a TF-IDF Vectorizer with Ngram 2 and 3
tfidf_vec = TfidfVectorizer(stop_words='english', ngram_range=(2, 3), tokenizer=tokenize_and_stem, max_features=1000, use_idf=True)

# %%
import math
import turicreate as tc

# %%
def classification():
  for cat in all_categories:
    
    test_set = pd.read_csv(cat+'_final.csv', encoding='ISO-8859-1')
    test_set['soup'] = test_set['reviewText'].apply(clean_text)
    test_set['soup'] = test_set['soup'].apply(lambda x: remove_stopwords(x))

    # exclude thoses reviews from label_data2 that are in test dataset (by matching ids)
    df = dataset[~dataset._id.isin(test_set._id)]

    # Delete rows with empty subclasses from dataFrame
    indexNames = df[df['subclasses'] == '[]'].index
    df.drop(indexNames , inplace=True)

    # df = dataset.copy()

    # over sampling
    class_count_0, class_count_1 = df[cat].value_counts()
    class_0 = df[df[cat] == 0]
    class_1 = df[df[cat] == 1]
    class_1_over = class_1.sample(2*class_count_0, replace=True)
    df = pd.concat([class_1_over, class_0], axis=0)

    # df = df.sample(n=math.floor(0.8*len(dataset)), replace=False)

    X_train = df['soup']
    y_train = df[cat]
    xtrain_tfidf = tfidf_vec.fit_transform(X_train)

    X_test = test_set['soup']
    y_test = test_set['CORRECT']
    xtest_tfidf = tfidf_vec.transform(X_test)

    data = np.hstack((xtrain_tfidf.todense(), np.expand_dims(y_train.values, 1)))
    train_data_df = pd.DataFrame(data, columns=list(tfidf_vec.vocabulary_.keys()) + ['target'])
    train_data_df['target'] = train_data_df['target'].astype(int)

    # turicreate model
    model = tc.boosted_trees_classifier.create(tc.SFrame(data=train_data_df), target='target', max_iterations=2, max_depth=3)
    
    data = xtest_tfidf.todense()
    test_data_df = pd.DataFrame(data, columns=list(tfidf_vec.vocabulary_.keys()))
    y_pred = model.predict(tc.SFrame(data=test_data_df))


    # Performance metrics
    accuracy, precision, recall, f1score = get_performance(y_test, pd.Series(y_pred))
    print('Performance for ', cat, ' category:')
    print('Precision : ', 100 * precision)
    print('Recall : ', 100 * recall)
    print('F1-score : ', 100 * f1score)

# %%
classification()
