# %%
import warnings

import numpy as np
import pandas as pd

warnings.filterwarnings('ignore')

# Data Preprocessing & NLP
import nltk
from ast import literal_eval
from nltk.stem.porter import *
from sklearn.feature_extraction.text import TfidfVectorizer

nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /home/azalea/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/azalea/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Load Data

# %%
label_data = pd.read_csv('../Data/new_golden.csv', encoding='ISO-8859-1')

label_data['new_HLC1'] = label_data['new_HLC'].apply(literal_eval)
label_data['new_LLC1'] = label_data['new_LLC'].apply(literal_eval)

label_data.head()
label_data.shape
# Out:
# (1584, 20)

# %%
# Data Cleaning
def clean_text(text):
    # remove everything except alphabets
    text = re.sub("[^a-zA-Z]", " ", text)
    # remove whitespaces
    text = ' '.join(text.split())
    text = text.lower()
    
    return text

# creating clean text feature
features = ['reviewText']
for feature in features:
    label_data['clean_' + feature] = label_data[feature].apply(clean_text)

label_data.head()
# Out:
#    Unnamed: 0                       _id                  new_HLC  \
# 0           0  578945a6819cb706b00a7328     ['USAGE', 'PRICING']
# 1           1  578945a5819cb706b00a7327  ['USAGE', 'RESSOURCES']
# 2           2  578945a5819cb706b00a7326  ['USAGE', 'RESSOURCES']
# 3           3  578945a5819cb706b00a7325                       []
# 4           4  578945a2819cb706b00a7324        ['COMPATIBILITY']
#
#                                   new_LLC   app appVersion  \
# 0          ['APP USABILITY', 'LICENSING']  2048       2.06
# 1  ['PERFORMANCE', 'APP USABILITY', 'UI']  2048       2.06
# 2                   ['PERFORMANCE', 'UI']  2048       2.06
# 3                               ['OTHER']  2048       2.06
# 4                     ['ANDROID VERSION']  2048       2.06
#
#                                           reviewText                   author  \
# 0  Fundamental flaw Sometimes drops a 4 instead o...                  Larry H
# 1  Too easy and too slow Being able to undo just ...  JÐ_hann G. ÐÐ¢lafsson
# 2  Slow Since latest update, it's moving very slo...           Zachary Burris
# 3     love it.. good excercise before i go to work..               ahmir Cruz
# 4  Keeps crashing Since I upgraded my android thi...       Astrid Elkesdottir
#
#        date  ratingStars  ... classification           class1         class2  \
# 0  15/01/16            4  ...          OTHER        LICENSING  APP USABILITY
# 1  18/01/16            2  ...          USAGE    APP USABILITY    PERFORMANCE
# 2  15/02/16            4  ...     RESSOURCES      PERFORMANCE    PERFORMANCE
# 3  20/02/16            5  ...          OTHER            OTHER            NaN
# 4  26/02/16            1  ...     RESSOURCES  ANDROID VERSION          ERROR
#
#   class3 copied to 30each class4 class5             new_HLC1  \
# 0  ERROR              NaN    NaN    NaN     [USAGE, PRICING]
# 1     UI                y  ERROR    NaN  [USAGE, RESSOURCES]
# 2     UI                y  ERROR    NaN  [USAGE, RESSOURCES]
# 3    NaN              NaN    NaN    NaN                   []
# 4    NaN                y    NaN    NaN      [COMPATIBILITY]
#
#                            new_LLC1  \
# 0        [APP USABILITY, LICENSING]
# 1  [PERFORMANCE, APP USABILITY, UI]
# 2                 [PERFORMANCE, UI]
# 3                           [OTHER]
# 4                 [ANDROID VERSION]
#
#                                     clean_reviewText
# 0  fundamental flaw sometimes drops a instead of ...
# 1  too easy and too slow being able to undo just ...
# 2  slow since latest update it s moving very slow...
# 3         love it good excercise before i go to work
# 4  keeps crashing since i upgraded my android thi...
#
# [5 rows x 21 columns]

# %%
label_data['soup'] = label_data['clean_reviewText']

def random_color_func(word=None, font_size=None, position=None,
                      orientation=None, font_path=None, random_state=None):
    h = int(360.0 * 55.0 / 255.0)
    s = int(100.0 * 255.0 / 255.0)
    l = int(100.0 * float(random_state.randint(70, 120)) / 255.0)
    return "hsl({}, {}%, {}%)".format(h, s, l)

def freq_words(x, terms = 50):
    all_words = ' '.join([text for text in x])
    all_words = all_words.split()
    
    freq_dist = nltk.FreqDist(all_words)
    words_df = pd.DataFrame({'word':list(freq_dist.keys()), 'count':list(freq_dist.values())})
    
    fig = plt.figure(figsize=(21,16))
    ax1 = fig.add_subplot(2,1,1)
    wordcloud = WordCloud(width=1000, height=300, background_color='black', 
                          max_words=1628, relative_scaling=1,
                          color_func = random_color_func,
                          normalize_plurals=False).generate_from_frequencies(freq_dist)
    
    ax1.imshow(wordcloud, interpolation="bilinear")
    ax1.axis('off')
    
    # select top 30 most frequent word
    ax2 = fig.add_subplot(2,1,2)
    d = words_df.nlargest(columns="count", n = terms) 
    ax2 = sns.barplot(data=d, palette = sns.color_palette('BuGn_r'), x= "count", y = "word")
    ax2.set(ylabel= 'Word')
    plt.show()


# Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

sns.set()
# %matplotlib inline
word = freq_words(label_data['soup'])

# %% [markdown]
# # Stop Word Removing

# %%
# stopwords-to compare text data with and without stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# function to remove stopwords
def remove_stopwords(text):
    no_stopword_text = [w for w in text.split() if not w in stop_words]
    return ' '.join(no_stopword_text)
  
label_data['soup'] = label_data['soup'].apply(lambda x: remove_stopwords(x))

# plot 50 most frequent words without stopwords
freq_words(label_data['soup'], 50)
# Out:
# [nltk_data] Downloading package stopwords to /home/azalea/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#total words count of user reviews
wordcounts = []
sentences = label_data['soup']
for sentence in sentences:

  words = sentence.split(' ')
  wordcounts.append(len(words))
print(sum(wordcounts))
# Out:
# 18265

# %% [markdown]
# # Stemming Process

# %%
# stemming process
'''
Words in the third person are changed to first person and verbs in past and future tenses are changed into the present by the 
stemming process. 
'''
stem_process = PorterStemmer()

def tokenize_and_stem(text):
    # tokenization to ensure that punctuation is caught as its own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    lem = [stem_process.stem(t) for t in filtered_tokens]
    return lem

# %% [markdown]
# # TF-IDF and N-Gram Process

# %%
# Defining a TF-IDF Vectorizer with Ngram 2 and 3
tfidf_vec = TfidfVectorizer(stop_words='english', ngram_range=(2, 3), tokenizer=tokenize_and_stem, max_features=10000, use_idf=True)

# %%
label_data.head()
# Out:
#    Unnamed: 0                       _id                  new_HLC  \
# 0           0  578945a6819cb706b00a7328     ['USAGE', 'PRICING']
# 1           1  578945a5819cb706b00a7327  ['USAGE', 'RESSOURCES']
# 2           2  578945a5819cb706b00a7326  ['USAGE', 'RESSOURCES']
# 3           3  578945a5819cb706b00a7325                       []
# 4           4  578945a2819cb706b00a7324        ['COMPATIBILITY']
#
#                                   new_LLC   app appVersion  \
# 0          ['APP USABILITY', 'LICENSING']  2048       2.06
# 1  ['PERFORMANCE', 'APP USABILITY', 'UI']  2048       2.06
# 2                   ['PERFORMANCE', 'UI']  2048       2.06
# 3                               ['OTHER']  2048       2.06
# 4                     ['ANDROID VERSION']  2048       2.06
#
#                                           reviewText                   author  \
# 0  Fundamental flaw Sometimes drops a 4 instead o...                  Larry H
# 1  Too easy and too slow Being able to undo just ...  JÐ_hann G. ÐÐ¢lafsson
# 2  Slow Since latest update, it's moving very slo...           Zachary Burris
# 3     love it.. good excercise before i go to work..               ahmir Cruz
# 4  Keeps crashing Since I upgraded my android thi...       Astrid Elkesdottir
#
#        date  ratingStars  ...           class1         class2 class3  \
# 0  15/01/16            4  ...        LICENSING  APP USABILITY  ERROR
# 1  18/01/16            2  ...    APP USABILITY    PERFORMANCE     UI
# 2  15/02/16            4  ...      PERFORMANCE    PERFORMANCE     UI
# 3  20/02/16            5  ...            OTHER            NaN    NaN
# 4  26/02/16            1  ...  ANDROID VERSION          ERROR    NaN
#
#   copied to 30each class4 class5             new_HLC1  \
# 0              NaN    NaN    NaN     [USAGE, PRICING]
# 1                y  ERROR    NaN  [USAGE, RESSOURCES]
# 2                y  ERROR    NaN  [USAGE, RESSOURCES]
# 3              NaN    NaN    NaN                   []
# 4                y    NaN    NaN      [COMPATIBILITY]
#
#                            new_LLC1  \
# 0        [APP USABILITY, LICENSING]
# 1  [PERFORMANCE, APP USABILITY, UI]
# 2                 [PERFORMANCE, UI]
# 3                           [OTHER]
# 4                 [ANDROID VERSION]
#
#                                     clean_reviewText  \
# 0  fundamental flaw sometimes drops a instead of ...
# 1  too easy and too slow being able to undo just ...
# 2  slow since latest update it s moving very slow...
# 3         love it good excercise before i go to work
# 4  keeps crashing since i upgraded my android thi...
#
#                                                 soup
# 0  fundamental flaw sometimes drops instead suspe...
# 1  easy slow able undo one move enough correct fa...
# 2  slow since latest update moving slow animation...
# 3                        love good excercise go work
# 4  keeps crashing since upgraded android game kee...
#
# [5 rows x 22 columns]

# %% [markdown]
# # Drop Null Values

# %%
def drop_null_values():
  df1 = label_data
  df2 = label_data
  # drop those rows with empty HLC
  for index, row in df1.iterrows():
    if row['new_HLC1'] == ['']:
      df1 = df1.drop(index)

  # drop those rows with empty LLC
  for index, row in df2.iterrows():
    if row['new_LLC1'] == ['']:
      df2 = df2.drop(index)

  return df1, df2


df1, df2 = drop_null_values()
print(df1.shape)
print(df2.shape)
# Out:
# (1584, 22)
# (1584, 22)

# %% [markdown]
# # Categories Levels

# %%
HLC_categories = ['USAGE', 'COMPATIBILITY', 'RESSOURCES', 'PRICING', 'PROTECTION']
LLC_categories = ['APP USABILITY', 'UI', 'DEVICE', 'ANDROID VERSION', 'HARDWARE', 'PERFORMANCE', 'BATTERY', 'MEMORY', 'LICENSING', 'PRICE', 'PRIVACY', 'SECURITY']

for cat in HLC_categories:
  df1[cat] = np.nan
  for index, row in df1.iterrows():
    if cat in row['new_HLC1']:
      df1.at[index,cat] = 1
    else:
      df1.at[index,cat] = 0

for cat in LLC_categories:
  df2[cat] = np.nan
  for index, row in df2.iterrows():
    if cat in row['new_LLC1']:
      df2.at[index,cat] = 1
    else:
      df2.at[index,cat] = 0

# %%
text = " ".join(review for review in label_data.clean_reviewText)
wordcloud = WordCloud(width=1600, height=800,max_font_size=200, colormap='magma').generate(text)

plt.figure(figsize = (12, 10))
plt.imshow(wordcloud, interpolation='spline36')
plt.axis("off")
plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.multiclass import OneVsRestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support as score

def get_performance(y_test, y_pred1):
    # Evaluate Performance
    accuracy = round(accuracy_score(y_test, y_pred1) * 100, 2)
    # Get precision, recall, f1 scores
    precision, recall, f1score, support = score(y_test, y_pred1, average='binary')
    return accuracy, precision, recall, f1score

def classification():
  for cat in HLC_categories:
    X_train, X_test, y_train, y_test = train_test_split(df1['soup'], df1[cat], test_size=0.2, random_state=55)
    xtrain_tfidf = tfidf_vec.fit_transform(X_train)
    xtest_tfidf = tfidf_vec.transform(X_test)
    
    gb_clf2 = GradientBoostingClassifier(n_estimators=60, learning_rate=1.0, max_depth=2)
    oneVsRest = OneVsRestClassifier(gb_clf2)

    oneVsRest.fit(xtrain_tfidf, y_train)
    y_pred1 = oneVsRest.predict(xtest_tfidf)

    # Performance metrics
    accuracy, precision, recall, f1score = get_performance(y_test, y_pred1)
    print('Performance for ', cat, ' category:')
    print('Accuracy : ', accuracy)
    print('Precision : ', 100 * precision)
    print('Recall : ', 100 * recall)
    print('F1-score : ', 100 * f1score)

  for cat in LLC_categories:
    X_train, X_test, y_train, y_test = train_test_split(df2['soup'], df2[cat], test_size=0.2, random_state=55)
    xtrain_tfidf = tfidf_vec.fit_transform(X_train)
    xtest_tfidf = tfidf_vec.transform(X_test)
    
    gb_clf2 = GradientBoostingClassifier(n_estimators=60, learning_rate=1.0, max_depth=2)
    oneVsRest = OneVsRestClassifier(gb_clf2)

    oneVsRest.fit(xtrain_tfidf, y_train)
    y_pred1 = oneVsRest.predict(xtest_tfidf)

    # Performance metrics
    accuracy, precision, recall, f1score = get_performance(y_test, y_pred1)
    print('Performance for ', cat, ' category:')
    print('Accuracy : ', accuracy)
    print('Precision : ', 100 * precision)
    print('Recall : ', 100 * recall)
    print('F1-score : ', 100 * f1score)

# %%
classification()
# Out:
# Performance for  USAGE  category:
# Accuracy :  72.56
# Precision :  50.0
# Recall :  26.436781609195403
# F1-score :  34.58646616541354
# Performance for  COMPATIBILITY  category:
# Accuracy :  82.33
# Precision :  65.625
# Recall :  31.818181818181817
# F1-score :  42.85714285714286
# Performance for  RESSOURCES  category:
# Accuracy :  89.59
# Precision :  77.27272727272727
# Recall :  37.77777777777778
# F1-score :  50.74626865671642
# Performance for  PRICING  category:
# Accuracy :  95.58
# Precision :  50.0
# Recall :  21.428571428571427
# F1-score :  30.0
# Performance for  PROTECTION  category:
# Accuracy :  92.74
# Precision :  87.5
# Recall :  24.137931034482758
# F1-score :  37.83783783783784

# %%
# for reviews.csv
label_data2 = pd.read_csv('reviews.csv', encoding='ISO-8859-1')

# change name of columns (remove 'IS_')
for col in label_data2.columns[15:]:
    label_data2 = label_data2.rename(columns = {col:col[3:]})

# Data Cleaning
label_data2['clean_reviewText'] = label_data2['reviewText'].apply(clean_text)
label_data2['soup'] = label_data2['clean_reviewText']

# %%
sns.set()
# %matplotlib inline
word = freq_words(label_data2['soup'])

label_data2['soup'] = label_data2['soup'].apply(lambda x: remove_stopwords(x))

# # plot 50 most frequent words without stopwords
freq_words(label_data2['soup'], 50)


# total words count of user reviews
wordcounts = []
sentences = label_data2['soup']
for sentence in sentences:
  words = sentence.split(' ')
  wordcounts.append(len(words))
print(sum(wordcounts))
# Out:
# 91992

# %%
text = " ".join(review for review in label_data2.clean_reviewText)
wordcloud = WordCloud(width=1600, height=800,max_font_size=200, colormap='magma').generate(text)

plt.figure(figsize = (12, 10))
plt.imshow(wordcloud, interpolation='spline36')
plt.axis("off")
plt.show()

# %%
df1 = label_data2
df2 = label_data2
df2.shape
# Out:
# (7754, 35)

# %%
print(df1.shape)
classification()
# Out:
# (7754, 35)
# Performance for  USAGE  category:
# Accuracy :  80.14
# Precision :  89.65517241379311
# Recall :  38.80597014925373
# F1-score :  54.16666666666667
# Performance for  COMPATIBILITY  category:
# Accuracy :  91.36
# Precision :  77.92207792207793
# Recall :  33.89830508474576
# F1-score :  47.24409448818897
# Performance for  RESSOURCES  category:
# Accuracy :  93.75
# Precision :  71.15384615384616
# Recall :  31.092436974789916
# F1-score :  43.2748538011696
# Performance for  PRICING  category:
# Accuracy :  95.1
# Precision :  80.3921568627451
# Recall :  38.31775700934579
# F1-score :  51.89873417721519
# Performance for  PROTECTION  category:
# Accuracy :  93.62
# Precision :  86.8421052631579
# Recall :  42.58064516129032
# F1-score :  57.14285714285714
# Performance for  APP USABILITY  category:
# Accuracy :  94.65
# Precision :  79.22077922077922
# Recall :  47.65625
# F1-score :  59.51219512195123
# Performance for  UI  category:
# Accuracy :  82.91
# Precision :  84.7457627118644
# Recall :  38.659793814432994
# F1-score :  53.09734513274337
# Performance for  DEVICE  category:
# Accuracy :  95.49
# Precision :  82.92682926829268
# Recall :  35.051546391752574
# F1-score :  49.27536231884058
# Performance for  ANDROID VERSION  category:
# Accuracy :  96.58
# Precision :  38.095238095238095
# Recall :  16.666666666666664
# F1-score :  23.18840579710145
# Performance for  HARDWARE  category:
# Accuracy :  97.55
# Precision :  78.57142857142857
# Recall :  40.74074074074074
# F1-score :  53.658536585365844
# Performance for  PERFORMANCE  category:
# Accuracy :  94.07
# Precision :  69.56521739130434
# Recall :  29.09090909090909
# F1-score :  41.02564102564102
# Performance for  BATTERY  category:
# Accuracy :  98.9
# Precision :  75.0
# Recall :  48.0
# F1-score :  58.536585365853654
# Performance for  MEMORY  category:
# Accuracy :  98.65
# Precision :  66.66666666666666
# Recall :  50.0
# F1-score :  57.14285714285715
# Performance for  LICENSING  category:
# Accuracy :  98.13
# Precision :  91.66666666666666
# Recall :  55.932203389830505
# F1-score :  69.47368421052632
# Performance for  PRICE  category:
# Accuracy :  96.71
# Precision :  65.85365853658537
# Recall :  42.1875
# F1-score :  51.42857142857142
# Performance for  PRIVACY  category:
# Accuracy :  96.65
# Precision :  19.047619047619047
# Recall :  10.256410256410255
# F1-score :  13.333333333333334
# Performance for  SECURITY  category:
# Accuracy :  95.36
# Precision :  80.95238095238095
# Recall :  54.83870967741935
# F1-score :  65.38461538461537
